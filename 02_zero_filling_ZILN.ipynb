# %% [markdown]
# ### 🧬 Non-Zero Abundance Counts per Group
#
# This script analyzes an OTU (or taxonomic) abundance table and counts how many samples in each experimental group have **non-zero abundance** for each taxon (e.g., genus).
#
# #### ✅ Functionality
#
# - Reads a taxonomic relative abundance table (CSV format).
# - Extracts **group names** from sample column prefixes (e.g., "Control1", "Control2" → "Control").
# - For each taxon, counts how many samples in each group show **non-zero** abundance.
# - Appends a final row with the total number of samples in each group.
#
# #### 🛠️ Requirements
#
# - Input CSV file: rows = taxa (e.g., genera), columns = sample names.
# - Sample names must begin with a group prefix (e.g., `Group1_sample1`).
#
# #### 📤 Output
#
# - A table where rows = taxa, columns = groups
# - Each cell = number of samples in that group with non-zero relative abundance
# - One final row `"Total Samples"` reports group sizes
#
# #### 📁 Example output file

# %%
import pandas as pd

# Load OTU table (taxa abundance matrix)
file_path = r'..abundance.csv'  # Replace with your actual file path
otu_df = pd.read_csv(file_path)

# Set the taxonomy column (e.g. genus names) as index
otu_df.set_index(otu_df.columns[0], inplace=True)

# Extract sample names and determine group labels (based on prefix)
samples = otu_df.columns
groups = samples.str.extract(r'^([A-Za-z]+)')[0]  # Extract the alphabetical prefix as group label

# Define function: count how many samples in each group have non-zero abundance per taxon
def count_nonzeros_by_group(data, groups):
    result = pd.DataFrame(index=data.index)  # Store per-group counts per taxon
    group_sample_counts = {}  # Keep track of how many samples in each group

    for group in groups.unique():
        group_columns = data.columns[groups == group]
        result[group] = (data[group_columns] > 0).sum(axis=1)  # Count non-zero samples
        group_sample_counts[group] = len(group_columns)  # Record total number of samples per group

    # Append a row showing how many total samples per group
    result.loc["Total Samples"] = pd.Series(group_sample_counts)
    return result

# Apply function to compute per-group nonzero counts
nonzero_counts = count_nonzeros_by_group(otu_df, groups)

# Print table
print("Non-zero abundance count table:")
print(nonzero_counts)

# Save result to file
output_file = r'..OTUTaxonAnalysis_Genus_MW_nonzero_counts_by_group.csv'  # Replace with output path
nonzero_counts.to_csv(output_file)

print(f"Count table saved to: {output_file}")

# %% [markdown]
# ### 🧬 Zero-Inflated Log-Normal (ZILN) Imputation for OTU Tables
#
# This module imputes zero values in a relative abundance OTU table using the **Zero-Inflated Log-Normal (ZILN)** model. It fits a log-normal distribution to the non-zero values for each taxon *within each group*, and replaces zeros with random values drawn from the fitted distribution.
#
# #### ✅ Functionality
#
# - Reads a relative abundance table (rows = taxa, columns = samples)
# - Sample names should contain a group prefix (e.g., "Control1", "Test2")
# - For each taxon:
#   - If all values are zero in all groups → exclude
#   - Else → fit log-normal to non-zero values and impute missing (zero) values
# - Removes taxa that cannot be fitted or have all-zero abundance
# - Saves a cleaned, filled OTU table
#
# #### 📥 Input
# - A `.csv` file of relative abundance data (e.g., genus-level)
# - Sample columns must be grouped by consistent name prefixes
#
# #### 📤 Output
# - A filled `.csv` file with zeros replaced (`*_filled_otu_table.csv`)
# - A list of removed taxa (`*_failed_taxa.csv`)
#
# #### 🧪 Use Case
# Use this step before network analysis or dimensionality reduction, to avoid sparsity artifacts while preserving group-specific abundance patterns.

# %%
import numpy as np
import pandas as pd
from scipy.stats import lognorm

# Load OTU relative abundance data
file_path = r'..relative_abundance.csv'  # Replace with your file path
otu_df = pd.read_csv(file_path)

# Set taxonomy column (e.g., genus names) as row index
otu_df.set_index(otu_df.columns[0], inplace=True)

# Extract sample names and determine group labels (based on sample prefix)
samples = otu_df.columns
groups = samples.str.extract(r'^([A-Za-z]+)')[0]  # Extract group prefix from sample names

# Define function: Impute zero values per group using Zero-Inflated Log-Normal (ZILN) model
def ziln_fill(data, groups):
    filled_data = pd.DataFrame(index=data.index, columns=data.columns)
    failed_taxa = []       # Taxa that failed log-normal fitting
    all_zero_taxa = []     # Taxa that have zero abundance in all samples

    for group in groups.unique():
        group_columns = data.columns[groups == group]
        group_data = data[group_columns]

        for taxon in group_data.index:
            row = group_data.loc[taxon]

            # Skip taxa with all-zero abundance
            if row.sum() == 0:
                all_zero_taxa.append(taxon)
                continue

            non_zero_values = row[row > 0]

            if len(non_zero_values) > 0:
                try:
                    # Fit log-normal distribution to non-zero values
                    shape, loc, scale = lognorm.fit(non_zero_values, floc=0)

                    # Generate replacement values for zero entries
                    zero_indices = row[row == 0].index
                    num_zeros = len(zero_indices)

                    if num_zeros > 0:
                        random_values = lognorm.rvs(shape, loc=loc, scale=scale, size=num_zeros)
                        row[zero_indices] = random_values

                except ValueError:
                    print(f"Failed to fit lognormal for {taxon} in group {group}. Adding to failed list.")
                    failed_taxa.append(taxon)
                    continue

            # Save the filled row
            filled_data.loc[taxon, group_columns] = row

    # Remove taxa that failed to fill or have all-zero abundance
    taxa_to_remove = list(set(all_zero_taxa + failed_taxa))
    filled_data = filled_data.drop(index=taxa_to_remove, errors='ignore')

    # Save removed taxa list
    failed_output_file = r'..failed_taxa.csv'
    pd.DataFrame(taxa_to_remove, columns=["Removed Taxa"]).to_csv(failed_output_file, index=False)
    print(f"Taxa that were removed (failed fit or all-zero) saved to: {failed_output_file}")

    return filled_data

# Apply the ZILN imputation function
otu_filled = ziln_fill(otu_df, groups)

# Print and save the result
print("ZILN-filled OTU table:")
print(otu_filled)

output_file = r'..filled_otu_table.csv'
otu_filled.to_csv(output_file)

print(f"Filled OTU table saved to: {output_file}")
# Out:
# Failed to fit lognormal for g__unclassified_o__Subgroup_2 in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Paludibaculum in group HNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Elev-16S-573 in group HNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__Subgroup_20 in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Smaragdicoccus in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Williamsia in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Angustibacter in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Oerskovia in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Pseudactinotalea in group HNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Intrasporangiaceae in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Amnibacterium in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Curtobacterium in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Rathayibacter in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Allocatelliglobosispora in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Hamadaea in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Rhizocola in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Amycolatopsis in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Actinoallomurus in group HNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__37-13 in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Chitinophaga in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Filimonas in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Flaviaesturariibacter in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Parasegetibacter in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Phaeodactylibacter in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Pontibacter in group HNG. Adding to failed list.
# Failed to fit lognormal for g__Fluviicola in group HNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__NS9_marine_group in group HNG. Adding to failed list.
# Failed to fit lognormal for g__
in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Fontimonas in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Thiohalorhabdus in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Thiotrichaceae in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Luteimonas in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Pseudoxanthomonas in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__Proteobacteria in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__SAR324_cladeMarine_group_B in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Turneriella in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Candidatus_Protochlamydia in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Simkaniaceae in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__cvE6 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__R76-B128 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Lenti-02 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__Omnitrophia in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Candidatus_Xiphinematobacter in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Opitutus in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Coraliomargarita in group LCG. Adding to failed list.
# Failed to fit lognormal for g__ADurb.Bin063-1 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Ellin516 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__Roseibacillus in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__WPS-2 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__WS4 in group LCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Elev-16S-573 in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__Blastocatellia in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__Subgroup_20 in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Williamsia in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Euzebya in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Angustibacter in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Brevibacterium in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Actinotalea in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Oerskovia in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Pseudactinotalea in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Brachybacterium in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Aquipuribacter in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Ornithinibacter in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Ornithinimicrobium in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Amnibacterium in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Galbitalea in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Myceligenerans in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Micrococcales in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Actinoallomurus in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Cnuella in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Pseudoflavitalea in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Taibaiella in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Cytophaga in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Chryseolinea in group HCG. Adding to failed list.
# Failed to fit lognormal for g__NS5_marine_group in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__NS9_marine_group in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Flavobacteriales in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__AKYH767 in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__KD3-93 in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Arcticibacter in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Mucilaginibacter in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Solitalea in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Sphingobacteriales in group HCG. Adding to failed list.
# Failed to fit lognormal for g__Balneola in group HCG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Ktedonobacteraceae in group HCG. Adding to failed list.
# ...
# Failed to fit lognormal for g__unclassified_o__Oscillospirales in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Peptococcaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Anaerovorax in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Paraclostridium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sporacetigenium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Terrisporobacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sedimentibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Gracilibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Heliobacteriaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Anaerosinus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Sporomusaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Veillonellales-Selenomonadales in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Symbiobacteraceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__Firmicutes in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__AKAU4049 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Longimicrobiaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__S0134_terrestrial_group in group MNG. Adding to failed list.
# Failed to fit lognormal for g__KD3-10 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Vulgatibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Nannocystis in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Nannocystaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sandaracinus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__4-29-1 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__ABY1 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Peribacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__Kazania in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Curtissbacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Pacebacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Woesebacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Woykebacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Brennerbacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Candidatus_Liptonbacteria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__GWA2-38-13b in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_c__BD7-11 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__S-70 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Rhodopirellula in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Planctomicrobium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Planctopirus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Acidocella in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Craurococcus-Caldovatus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Inquilinus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Caedibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Tagaea in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Methyloceanibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Hansschlegelia in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Prosthecomicrobium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Aureimonas in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Alsobacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Ancylobacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Rhodobacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Magnetospirillum in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Rhodospirillaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Mitochondria in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Rickettsiaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Polymorphobacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sphingoaurantiacus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sphingobium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Geminicoccus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sulfurifustis in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Ideonella in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Candidatus_Nitrotoga in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sideroxydans in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Gallionellaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Neisseriaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__DSSD61 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__P3OB-51 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Collimonas in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Herbaspirillum in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Azospira in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Dechloromonas in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Sulfuritalea in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__T34 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__CCM19a in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Thioalkalispiraceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Enterobacteriaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Ga0077536 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Cellvibrio in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Moraxellaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__BD1-7_clade in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Solimonadaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Luteibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Pseudofulvimonas in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Rudaea in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Tahibacter in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Stenotrophomonas in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Xanthomonadales in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Leptospiraceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Estrella in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Candidatus_Metachlamydia in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Parachlamydia in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Waddlia in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__01D2Z36 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Terrimicrobium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_f__Methylacidiphilaceae in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Alterococcus in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Opitutales in group MNG. Adding to failed list.
# Failed to fit lognormal for g__DEV114 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Ellin517 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Oikopleura in group MNG. Adding to failed list.
# Failed to fit lognormal for g__SH3-11 in group MNG. Adding to failed list.
# Failed to fit lognormal for g__Verrucomicrobium in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_o__Verrucomicrobiales in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__Verrucomicrobiota in group MNG. Adding to failed list.
# Failed to fit lognormal for g__unclassified_p__Zixibacteria in group MNG. Adding to failed list.
# 无法填充或所有组内均为 0 的属已保存到 D:\4 Cooperation\11. Usman\04. B Data\OTUTaxonAnalysis_Genus_MW_failed_taxa.csv
# 填充后的 OTU 表：
#                                             HNG4      HNG5      HNG1  \
# genus
# g__unclassified_c__AT-s3-28             0.000053  0.000183  0.000071
# g__unclassified_o__Acidobacteriales     0.000137   0.00055  0.000102
# g__unclassified_c__Acidobacteriae       0.000183   0.00015  0.000137
# g__unclassified_o__11-24                 0.00055  0.000412  0.000321
# g__RB41                                 0.025284  0.022353  0.024368
# ...                                          ...       ...       ...
# g__Steroidobacter                       0.001328  0.001603  0.001237
# g__unclassified_c__Gammaproteobacteria  0.000687  0.000504  0.000916
# g__Sumerlaea                            0.000137  0.000183  0.000137
# g__unclassified_f__Pedosphaeraceae      0.002931  0.001466   0.00197
# g__unclassified_d__Bacteria             0.007741  0.006229  0.008382
#
#                                             HNG2      HNG3      MCG3  \
# genus
# g__unclassified_c__AT-s3-28             0.000081  0.000046  0.000046
# g__unclassified_o__Acidobacteriales     0.000054  0.000046  0.006046
# g__unclassified_c__Acidobacteriae       0.000178  0.000137  0.000046
# g__unclassified_o__11-24                0.000321  0.001603  0.001786
# g__RB41                                 0.016169   0.03046  0.008153
# ...                                          ...       ...       ...
# g__Steroidobacter                       0.001328  0.002748  0.000412
# g__unclassified_c__Gammaproteobacteria  0.001374  0.000824  0.000779
# g__Sumerlaea                            0.000229  0.000137  0.000412
# g__unclassified_f__Pedosphaeraceae      0.001878   0.00229  0.001053
# g__unclassified_d__Bacteria             0.007283     0.006  0.006367
#
#                                             MCG1      MCG4      MCG5  \
# genus
# g__unclassified_c__AT-s3-28             0.000366  0.000229  0.000412
# g__unclassified_o__Acidobacteriales     0.010077  0.013421  0.014428
# g__unclassified_c__Acidobacteriae       0.000046  0.000092  0.000112
# g__unclassified_o__11-24                0.006184  0.005542  0.009756
# g__RB41                                 0.021894  0.017818  0.031742
# ...                                          ...       ...       ...
# g__Steroidobacter                        0.00055  0.000733  0.000824
# g__unclassified_c__Gammaproteobacteria  0.000229   0.00055   0.00055
# g__Sumerlaea                            0.000321  0.000321  0.000275
# g__unclassified_f__Pedosphaeraceae      0.003298  0.003252  0.002565
# g__unclassified_d__Bacteria             0.006138  0.005542  0.006871
#
#                                             MCG2  ...      LNG5      LNG1  \
# genus                                             ...
# g__unclassified_c__AT-s3-28             0.000183  ...  0.000127  0.000049
# g__unclassified_o__Acidobacteriales     0.020429  ...  0.000092  0.000092
# g__unclassified_c__Acidobacteriae       0.000321  ...  0.000321  0.001053
# g__unclassified_o__11-24                0.005084  ...  0.000129  0.000193
# g__RB41                                 0.019604  ...  0.000046  0.001695
# ...                                          ...  ...       ...       ...
# g__Steroidobacter                       0.000687  ...  0.000046  0.000092
# g__unclassified_c__Gammaproteobacteria  0.000366  ...  0.004809  0.002748
# g__Sumerlaea                            0.000229  ...  0.000275  0.000183
# g__unclassified_f__Pedosphaeraceae      0.002565  ...  0.001557  0.002153
# g__unclassified_d__Bacteria             0.007695  ...  0.010443  0.010627
#
#                                             LNG4      LNG2      LNG3  \
# genus
# g__unclassified_c__AT-s3-28             0.000053  0.000092  0.000046
# g__unclassified_o__Acidobacteriales     0.000046  0.000058  0.000229
# g__unclassified_c__Acidobacteriae       0.000824  0.000595  0.000595
# g__unclassified_o__11-24                0.000275  0.000147  0.000092
# g__RB41                                 0.000321  0.000137  0.000229
# ...                                          ...       ...       ...
# g__Steroidobacter                       0.000051  0.000092  0.000046
# g__unclassified_c__Gammaproteobacteria  0.003802  0.002702  0.003344
# g__Sumerlaea                            0.000229   0.00023  0.000137
# g__unclassified_f__Pedosphaeraceae      0.000641  0.003252  0.001695
# g__unclassified_d__Bacteria             0.007283  0.011268  0.009023
#
#                                             MNG4      MNG3      MNG1  \
# genus
# g__unclassified_c__AT-s3-28             0.000504  0.000366  0.000137
# g__unclassified_o__Acidobacteriales     0.014886  0.016215  0.011268
# g__unclassified_c__Acidobacteriae       0.000229  0.000046  0.000153
# g__unclassified_o__11-24                0.008291  0.005451  0.008245
# g__RB41                                 0.017268  0.017497  0.016948
# ...                                          ...       ...       ...
# g__Steroidobacter                       0.000504  0.000504  0.000595
# g__unclassified_c__Gammaproteobacteria  0.000366  0.000504  0.000412
# g__Sumerlaea                            0.000275  0.000229  0.000458
# g__unclassified_f__Pedosphaeraceae      0.003481  0.004443  0.003115
# g__unclassified_d__Bacteria             0.007329  0.006779  0.004168
#
#                                             MNG5      MNG2
# genus
# g__unclassified_c__AT-s3-28             0.000412  0.000824
# g__unclassified_o__Acidobacteriales     0.014199  0.014062
# g__unclassified_c__Acidobacteriae       0.000185  0.000092
# g__unclassified_o__11-24                0.008199  0.010901
# g__RB41                                 0.022078  0.028215
# ...                                          ...       ...
# g__Steroidobacter                       0.000779  0.001053
# g__unclassified_c__Gammaproteobacteria  0.000824  0.000275
# g__Sumerlaea                            0.000275  0.000366
# g__unclassified_f__Pedosphaeraceae      0.002107  0.004535
# g__unclassified_d__Bacteria             0.005542  0.006092
#
# [135 rows x 30 columns]
# 填充后的 OTU 表已保存到 D:\4 Cooperation\11. Usman\04. B Data\OTUTaxonAnalysis_Genus_MW_filled_otu_table.csv
